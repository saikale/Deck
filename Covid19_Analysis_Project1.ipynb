# %% [markdown]
# <a href="https://colab.research.google.com/github/saikale/Deck/blob/main/Covid19_Analysis_Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)

# %%
data=pd.read_csv('/content/vaccine_doses_statewise_v2.csv')

# %%
data.head()
# Out:
#   Vaccinated As of  ... Total Doses Administered
# 0       16/01/2021  ...                    225.0
# 1       16/01/2021  ...                  18412.0
# 2       16/01/2021  ...                    829.0
# 3       16/01/2021  ...                   3528.0
# 4       16/01/2021  ...                  18169.0
#
# [5 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9766 entries, 0 to 9765
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Vaccinated As of          9766 non-null   object
#  1   State                     9766 non-null   object
#  2   First Dose Administered   9691 non-null   float64
#  3   Second Dose Administered  9691 non-null   float64
#  4   Total Doses Administered  9691 non-null   float64
# dtypes: float64(3), object(2)
# memory usage: 381.6+ KB

# %%
sns.barplot(data['Vaccinated As of'], data['Total Doses Administered'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot(data['State'], data['Total Doses Administered'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.distplot(data['Total Doses Administered'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data['Total Doses Administered'], kde=False, rug=True);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
sns.jointplot(data['Total Doses Administered'], data['State'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.stripplot(data['State'],data['Total Doses Administered'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(data['Total Doses Administered'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
from bs4 import BeautifulSoup
import requests

# %%
def population():
    r = requests.get("https://www.worldometers.info/world-population/india-population/")
    soup = BeautifulSoup(r.content, 'html.parser')
    target = soup.find(
        "div", class_="col-md-8 country-pop-description").find_all_next("strong")[1]
    return (target.text)

# %%
total_pop= population()
total_pop=total_pop.replace(",","")
print(total_pop)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-08983fc88b62> in <module>()
# ----> 1 total_pop= population()
#       2 total_pop=total_pop.replace(",","")
#       3 print(total_pop)
#
# <ipython-input-15-4851bd16ad4b> in population()
#       3     soup = BeautifulSoup(r.content, 'html.parser')
#       4     target = soup.find(
# ----> 5         "div", class_="col-md-8 country-pop-description").find_all_next("strong")[1]
#       6     return (target.text)
#
# AttributeError: 'NoneType' object has no attribute 'find_all_next'

# %%
def vaccination_done():
    r = requests.get('https://www.mygov.in/covid-19')
    soup = BeautifulSoup(r.content,'html.parser')
    target = soup.find(
        "div", class_="total-vcount").find_all_next("strong")[0]
    return (target.text)

# %%
total_vaccinated = vaccination_done()
total_vaccinated=total_vaccinated.replace(",","")
#print(total_vaccinated)

# %%
def avg_vaccination_daily():
    r = requests.get('https://www.mygov.in/covid-19')
    soup = BeautifulSoup(r.content, 'html.parser')
    target = soup.find(
        "div", class_="yday-vcount").find_all_next("strong")[0]
    return (target.text)

# %%
daily_vaccination = avg_vaccination_daily()
daily_vaccination=daily_vaccination.replace(",","")
print(daily_vaccination)

# %%
print('Total days left to complete vaccination process in India is :' + str(round(days_left)))
